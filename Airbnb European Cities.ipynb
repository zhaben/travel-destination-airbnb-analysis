# %% [markdown]
# # Airbnb European Cities

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/thedevastator/airbnb-prices-in-european-cities?resource=download

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os_files = os.listdir("/Users/zhanebennett/Downloads/archive")

# %%
dfs = []
path = "/Users/zhanebennett/Downloads/archive"

for file in os_files:
    df = pd.read_csv(os.path.join(path, file))
    df['City'] = file.split('_')[0]
    df['Time_of_week'] = file.split('_')[1][:-4]
    dfs.append(df) #list of dataframes

# %%
df_combined = pd.concat(dfs)

# %%
df_combined.drop(columns=df_combined.columns[0], axis=1, inplace=True)

# %%
df = df_combined.copy()

# %%
df.sort_values('dist').head()
# Out:
#           realSum        room_type  room_shared  room_private  \
# 585   1413.540178  Entire home/apt        False         False
# 666    995.477234  Entire home/apt        False         False
# 1923   209.851013  Entire home/apt        False         False
# 1421   266.460977  Entire home/apt        False         False
# 1607   417.225240     Private room        False          True
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 585               4.0              False      0    0                 7.0
# 666               4.0              False      0    0                 7.0
# 1923              3.0              False      0    0                10.0
# 1421              4.0               True      0    1                10.0
# 1607              2.0              False      0    0                10.0
#
#       guest_satisfaction_overall  ...      dist  metro_dist   attr_index  \
# 585                         84.0  ...  0.015045    0.249495  1003.273083
# ...

# %%
df.describe()
# Out:
#             realSum  person_capacity         multi           biz  \
# count  51707.000000     51707.000000  51707.000000  51707.000000
# mean     279.879591         3.161661      0.291353      0.350204
# std      327.948386         1.298545      0.454390      0.477038
# min       34.779339         2.000000      0.000000      0.000000
# 25%      148.752174         2.000000      0.000000      0.000000
# 50%      211.343089         3.000000      0.000000      0.000000
# 75%      319.694287         4.000000      1.000000      1.000000
# max    18545.450285         6.000000      1.000000      1.000000
#
#        cleanliness_rating  guest_satisfaction_overall     bedrooms  \
# count        51707.000000                51707.000000  51707.00000
# mean             9.390624                   92.628232      1.15876
# std              0.954868                    8.945531      0.62741
# min              2.000000                   20.000000      0.00000
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df[(df['City'] == "budapest")], x = 'dist', y = "realSum", hue = "room_type")
# Out:
# <AxesSubplot:xlabel='dist', ylabel='realSum'>

# %%
x = df['City']
y = df['realSum']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))

plt.title('Airbnb Average Price per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=15);
 
# Horizontal Bar Plot
plt.bar(x, y)
 
# Show Plot
plt.show()

# %%
x = df['Time_of_week']
y = df['realSum']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Airbnb Average Price per Time of Week', fontsize=20)
plt.xlabel('Day of Week', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=0);
 
# Horizontal Bar Plot
plt.bar(x, y)

# Show Plot
plt.show()

# %%
x = df['cleanliness_rating']
y = df['dist']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
plt.title('Airbnb Average Distane from City Center per Cleanliness Rating', fontsize=20)
plt.xlabel('Cleanliness Rating', fontsize=16);
plt.ylabel('Distance from City Center', fontsize=16);
plt.xticks(fontsize=14, rotation=0);  
    
# Horizontal Bar Plot
plt.bar(x, y)

# Show Plot
plt.show()

# %%
x = df['City']
y = df['dist']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(x, y)

plt.title('Airbnb Average Distance from City Center per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Distance', fontsize=16);
plt.xticks(fontsize=14, rotation=15);

# Show Plot
plt.show()

# %%
import seaborn as sns
grouped_city = df.groupby(['City', 'Time_of_week'])['realSum'].mean().reset_index()
grouped_city

sns.barplot(data=grouped_city, x = 'realSum', y = "City", hue = "Time_of_week");

plt.title('Airbnb Average Price per City per Time of Week', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'dist', y = "City")

plt.title('Airbnb Average Distance from City Center per City', fontsize=20)
plt.xlabel('Distance from City Center', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['metro_dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'metro_dist', y = "City")#, hue="Time_of_week");

plt.title('Airbnb Average Distance from Metro per City', fontsize=20)
plt.xlabel('Distance from Metro', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['metro_dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'metro_dist', y = "City", hue="Time_of_week");

plt.title('Airbnb Average Distance from Metro per City per Time of Week', fontsize=20)
plt.xlabel('Distance from Metro', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
klxncknsdcalkna_type'])['dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'dist', y = "City", hue='room_type');

plt.title('Airbnb Listings Average Distance from City Center', fontsize=20)
plt.xlabel('Average Distance from City Center (miles)', fontsize=12);
plt.ylabel('City', fontsize=12);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df[df['room_type'] == 'Entire home/apt'].groupby(['City', 'room_type'])['dist'].mean().reset_index().sort_values('dist')
grouped_1
sns.barplot(data=grouped_1, x = 'dist', y = "City", hue="room_type");

plt.title('Airbnb Listings Average Distance from City Center', fontsize=20)
plt.xlabel('Average Distance from City Center (miles)', fontsize=12);
plt.ylabel('City', fontsize=12);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'room_type'])['realSum'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'realSum', y = "City", hue='room_type');

plt.title('Airbnb Average Price per City per Room Type', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %% [markdown]
# ## Scatter Plots

# %%
bx = df.plot(kind='scatter', x='dist',y='realSum',color = 'Green',label ='f')

# %%
sns.scatterplot(data=df[df['realSum'] < 3000], x = 'metro_dist', y = "realSum", hue = "City", alpha=.2)

#df_combined[df_combined['real_sum'] < 5000]
# Out:
# <AxesSubplot:xlabel='metro_dist', ylabel='realSum'>

# %%
sns.scatterplot(data=df[(df['realSum'] < 5000) & (df['City'] == "vienna")], x = 'metro_dist', y = "realSum", hue = "City")
# Out:
# <AxesSubplot:xlabel='metro_dist', ylabel='realSum'>

# %%
g = sns.FacetGrid(df, col="City")
g.map_dataframe(sns.scatterplot, x="dist", y="realSum")

# %% [markdown]
# # Histograms

# %%
df.hist(bins=30, figsize=(15, 10));

# %% [markdown]
# # Correlation Matrices

# %%
#plt.matshow(df.corr())
#plt.show()

f = plt.figure(figsize=(8, 6))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=10, rotation=75)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
import pandas as pd
import numpy as np

#rs = np.random.RandomState(0)
#df = pd.DataFrame(rs.rand(10, 10))
corr = df[["realSum", "room_shared", "room_private", "person_capacity", "host_is_superhost", "multi", "biz", "cleanliness_rating", "guest_satisfaction_overall", "bedrooms", "dist", "metro_dist"]].corr()
corr.style.background_gradient(cmap='coolwarm')

################################################
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null('#f1f1f1')  # Color NaNs grey
 .format(precision=2))
# Out:
# <style type="text/css">
# ...

# %%
#List of correlated values
df.corr().unstack().sort_values().drop_duplicates()
# Out:
# person_capacity             room_private         -0.499993
# biz                         multi                -0.470725
# rest_index_norm             dist                 -0.467791
# attr_index                  dist                 -0.363088
# dist                        rest_index           -0.346653
#                                                     ...
# rest_index_norm             rest_index            0.617970
# guest_satisfaction_overall  cleanliness_rating    0.714045
# attr_index                  attr_index_norm       0.714847
# rest_index                  attr_index            0.850229
# realSum                     realSum               1.000000
# Length: 154, dtype: float64

# %%
#List of correlated values - absolute value
df.corr().abs().unstack().sort_values().drop_duplicates()
# Out:
# multi               bedrooms                      0.000659
# metro_dist          host_is_superhost             0.000722
# realSum             guest_satisfaction_overall    0.001888
# metro_dist          room_shared                   0.002868
# person_capacity     cleanliness_rating            0.003256
#                                                     ...
# rest_index          rest_index_norm               0.617970
# cleanliness_rating  guest_satisfaction_overall    0.714045
# attr_index_norm     attr_index                    0.714847
# rest_index          attr_index                    0.850229
# realSum             realSum                       1.000000
# Length: 154, dtype: float64

# %% [markdown]
# # Bar Plot

# %%
df[['room_type', 'guest_satisfaction_overall']].hist(by='room_type', figsize=(18, 12))
# Out:
# array([[<AxesSubplot:title={'center':'Entire home/apt'}>,
#         <AxesSubplot:title={'center':'Private room'}>],
#        [<AxesSubplot:title={'center':'Shared room'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_sns = df.reset_index()

# %%
df.groupby('host_is_superhost')['guest_satisfaction_overall'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(4, 3))
# Out:
# <AxesSubplot:xlabel='host_is_superhost'>

# %%
o = df[df['realSum'].notnull()]
pivot = pd.pivot_table(data=o, index=['host_is_superhost'], columns=['room_type'], values='realSum')
pivot
# Out:
# room_type          Entire home/apt  Private room  Shared room
# host_is_superhost
# False                   341.279766     205.54976   140.967040
# True                    279.354366     202.86695   164.168972

# %%
ax = pivot.plot.bar(stacked=True, figsize=(8,6))
ax.set_title('Price per Room Time per Time of Week', fontsize=20)
ax.set_ylim(0,500)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);

# %%
df.groupby('room_type')['guest_satisfaction_overall'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(4, 3))
# Out:
# <AxesSubplot:xlabel='room_type'>

# %%
pivot = pd.pivot_table(data=df, index=['room_type'], columns=['Time_of_week'], values='realSum')
pivot
# Out:
# Time_of_week       weekdays    weekends
# room_type
# Entire home/apt  320.083367  328.379227
# Private room     202.169874  207.698465
# Shared room      139.105184  147.883241

# %%
ax = pivot.plot.bar(stacked=True, color =['lightseagreen', 'tomato'], figsize=(12,6))
ax.set_title('Price per Room Time per Time of Week', fontsize=20)
ax.set_ylim(0,500)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);

# %% [markdown]
# # Stats visuals

# %%
df.count()
# Out:
# realSum                       51707
# room_type                     51707
# room_shared                   51707
# room_private                  51707
# person_capacity               51707
# host_is_superhost             51707
# multi                         51707
# biz                           51707
# cleanliness_rating            51707
# guest_satisfaction_overall    51707
# bedrooms                      51707
# dist                          51707
# metro_dist                    51707
# attr_index                    51707
# attr_index_norm               51707
# rest_index                    51707
# rest_index_norm               51707
# lng                           51707
# lat                           51707
# City                          51707
# Time_of_week                  51707
# dtype: int64

# %% [markdown]
# ## Manage Outliers

# %%
import numpy as np

# %%
#Outliers

outliers = df[['realSum']].dropna()
df_outliers = df.loc[outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
#outliers2.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)
df_outliers.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
# 4  485.552926  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 0                        93.0  ...  5.022964    2.539380   78.690379
# 1                        85.0  ...  0.488389    0.239404  631.176378
# ...

# %%
df_outliers.count()
# Out:
# realSum                       51304
# room_type                     51304
# room_shared                   51304
# room_private                  51304
# person_capacity               51304
# host_is_superhost             51304
# multi                         51304
# biz                           51304
# cleanliness_rating            51304
# guest_satisfaction_overall    51304
# bedrooms                      51304
# dist                          51304
# metro_dist                    51304
# attr_index                    51304
# attr_index_norm               51304
# rest_index                    51304
# rest_index_norm               51304
# lng                           51304
# lat                           51304
# City                          51304
# Time_of_week                  51304
# dtype: int64

# %%
# Dataframe is now without outliers
df = df_outliers.copy()

# %%
normalized_df=(df-df.mean())/df.std() #mean
#normalized_df=(df-df.min())/(df.max()-df.min()) #max_min
# Out:
# /var/folders/vg/kzyxthxd3s52ww15y_mt_5rc0000gn/T/ipykernel_2637/1023475572.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   normalized_df=(df-df.mean())/df.std() #mean
# /var/folders/vg/kzyxthxd3s52ww15y_mt_5rc0000gn/T/ipykernel_2637/1023475572.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   normalized_df=(df-df.mean())/df.std() #mean

# %%
boxplot = normalized_df.boxplot(figsize=(15, 8))

plt.title('Box & Whisker Plot of Features', fontsize=20)
plt.xlabel('Features', fontsize=10);
plt.xticks(fontsize=10, rotation=75);

# %% [markdown]
# # Scatter Plot

# %%
from pandas.plotting import scatter_matrix
  
# selecting three numerical features
features = ['realSum','dist', 'metro_dist', 'cleanliness_rating']
   
#plotting the scatter matrix
#with the features
scatter_matrix(df[features])
plt.show()

# %%
sns.scatterplot(data=df, x = 'metro_dist', y = "cleanliness_rating", alpha=.2)
# Out:
# <AxesSubplot:xlabel='metro_dist', ylabel='cleanliness_rating'>

# %%
sns.scatterplot(data=df, x = 'dist', y = "cleanliness_rating", alpha=.2)
# Out:
# <AxesSubplot:xlabel='dist', ylabel='cleanliness_rating'>

# %%
df[['realSum']].plot(kind='hist', density=True,                            
        alpha=0.7,
        bins=100,
        title='Distribution Of Price',
        rot=45,
        grid=True,
        figsize=(12,8),
        fontsize=15, 
        color=['#A0E8AF', '#FFCF56'])
plt.xlabel('Price')
plt.ylabel("Number of Airbnb Rentals");

# %%
df_sns = df.reset_index()

# %%
import seaborn as sns
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=12,8

# set seaborn whitegrid theme
sns.set(style="whitegrid")

sns.kdeplot(data=df_sns, x="realSum", hue="City", fill=True, common_norm=False, alpha=0.3)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="room_type", fill=True, common_norm=False, alpha=0.4)
plt.show()

# %%
# using small multiple
# create a grid 
g = sns.FacetGrid(df_sns, col='room_type', hue='room_type', col_wrap=3)

# draw density plots
g = g.map(sns.kdeplot,"realSum", cut=0, fill=True, common_norm=False, alpha=1, legend=False)

# control the title of each facet
g = g.set_titles("{col_name}")

# show the graph
plt.show()

# %%
# using small multiple
# create a grid 
g = sns.FacetGrid(df_sns, col='City', hue='room_type', col_wrap=3)

# draw density plots
g = g.map(sns.kdeplot,"realSum", cut=0, fill=True, common_norm=False, alpha=.4, legend=False)

# control the title of each facet
g = g.set_titles("{col_name}")

# show the graph
plt.show()

# %%
sns.kdeplot(data=df_sns, x="dist", hue="City", fill=True, common_norm=False, alpha=0.2)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="metro_dist", hue="City", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="room_private", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="cleanliness_rating", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
# stacked density plot
sns.kdeplot(data=df, x="realSum", hue="cleanliness_rating", common_norm=False, multiple="fill", alpha=1)

# show the graph
plt.show()
# Out:
# /Users/zhanebennett/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 2>()
#       1 # stacked density plot
# ----> 2 sns.kdeplot(data=df, x="realSum", hue="cleanliness_rating", common_norm=False, multiple="fill", alpha=1)
#       4 # show the graph
#       5 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
# ...

# %%
# stacked density plot
sns.kdeplot(data=df, x="realSum", hue="host_is_superhost", fill=True, common_norm=False, alpha=.1)

# show the graph
plt.show()

# %% [markdown]
# # Box & Whisker Plots

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data = df, x="City", y="realSum")
'''
#Adjusted for prices under $5,000 instead of outlier
plt.figure(figsize=(15,8))
sns.boxplot(data = df[df['realSum'] < 5000], x="City", y="realSum")
'''

plt.title('Dsitribution of Prices per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
#Box & Whisker Plot Prices per City per Room Type
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="realSum", 
            y="City", 
            hue="room_type")

plt.title('Distribution of Prices by City by Room Type', fontsize=20)
plt.xlabel('Price (per night)', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
sns.scatterplot(data=df_outliers[(df_outliers['City'] == "budapest") & (df_outliers['dist'] <= 1)], x = 'dist', y = "realSum", hue = "room_type")

# %%
#Box & Whisker Plot Prices per City per Room Type
plt.figure(figsize=(15,8))
sns.boxplot(data = df[(df['dist'] <= 1) & (df['room_type'] == "Entire home/apt")], 
            x="realSum", 
            y="City",
           hue = "room_type")

plt.title('Distribution of Prices by City for Room Type: Entire home/apt', fontsize=20)
plt.xlabel('Price (per night)', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
df.groupby()

# %%
#Box & Whisker per Host Status
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="realSum", 
            y="City", 
            hue="host_is_superhost",
           width=.7)

plt.title('Distribution of Prices per City per Super Host Status', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
df["cleanliness_rating_str"] = df["cleanliness_rating"].astype(str)

# %%
#Box & Whisker per Host Status
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="metro_dist", 
            y="cleanliness_rating_str",
           width=.7)

plt.title('Distribution of Cleanliness Rating across Metro Distance', fontsize=20)
plt.xlabel('Distance from Metro', fontsize=16);
plt.ylabel('Cleanliness Rating', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
#Box & Whisker per Host Status
plt.figure(figsize=(15,8))
sns.boxplot(data = df[df["City"]=="vienna"], 
            x="dist", 
            y="cleanliness_rating_str",
           width=.7)

plt.title('Distribution of Cleanliness Rating across Distance from City Center', fontsize=20)
plt.xlabel('Distance from City Center', fontsize=16);
plt.ylabel('Cleanliness Rating', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
sns.kdeplot(data=df_sns[df_sns["City"]=="paris"], x="dist", hue="cleanliness_rating", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
sns.kdeplot(data=df_sns[df_sns["City"]=="budapest"], x="dist", hue="cleanliness_rating", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
# using small multiple
# create a grid 
g = sns.FacetGrid(df_sns, col='City', hue="cleanliness_rating", col_wrap=3)

# draw density plots
g = g.map(sns.kdeplot,"dist", cut=0, fill=True, common_norm=False, alpha=.1, legend=False)

# control the title of each facet
g = g.set_titles("{col_name}")

# show the graph
plt.show()
# Out:
# /Users/zhanebennett/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
df[df['City']== "barcelona"]['cleanliness_rating']
# Out:
# 0       10.0
# 1       10.0
# 2        9.0
# 3        9.0
# 4        9.0
#         ...
# 1549    10.0
# 1550     8.0
# 1551     9.0
# 1552    10.0
# 1554     9.0
# Name: cleanliness_rating, Length: 2817, dtype: float64

# %%
df['cleanliness_over_8'] = df['cleanliness_rating'] > 8

# %%
df
# Out:
#           realSum        room_type  room_shared  room_private  \
# 0      194.033698     Private room        False          True
# 1      344.245776     Private room        False          True
# 2      264.101422     Private room        False          True
# 3      433.529398     Private room        False          True
# 4      485.552926     Private room        False          True
# ...           ...              ...          ...           ...
# 5374  1035.066676     Private room        False          True
# 5375   181.095510     Private room        False          True
# 5376   420.517886  Entire home/apt        False         False
# 5377   217.314612     Private room        False          True
# 5378   489.193067  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                 2.0              False      1    0                10.0
# ...

# %%
grouped_city = df.groupby(['City', 'Time_of_week'])['realSum'].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [168], in <cell line: 1>()
# ----> 1 df['cleanliness_over_8_mean'] = mean(df['cleanliness_rating'] > 8)
#
# NameError: name 'mean' is not defined

# %%
df.groupby("City")["cleanliness_over_8"].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
df['dist_bucket'] = df['dist'] < 10

# %%
df['dist_bucket_str'] = df['dist_bucket'].astype(str)

# %%
df
# Out:
#           realSum        room_type  room_shared  room_private  \
# 0      194.033698     Private room        False          True
# 1      344.245776     Private room        False          True
# 2      264.101422     Private room        False          True
# 3      433.529398     Private room        False          True
# 4      485.552926     Private room        False          True
# ...           ...              ...          ...           ...
# 5374  1035.066676     Private room        False          True
# 5375   181.095510     Private room        False          True
# 5376   420.517886  Entire home/apt        False         False
# 5377   217.314612     Private room        False          True
# 5378   489.193067  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                 2.0              False      1    0                10.0
# ...

# %%
pivot = pd.pivot_table(data=df, index=['dist_bucket_str'], columns=['cleanliness_rating'], values='realSum')
pivot
# Out:
# cleanliness_rating        2.0         3.0         4.0         5.0   \
# dist_bucket_str
# False               201.509913         NaN  107.559758  248.594746
# True                292.779410  242.498889  320.599118  208.329965
#
# cleanliness_rating        6.0         7.0         8.0         9.0         10.0
# dist_bucket_str
# False               142.759542  188.468151  210.636796  186.472154  187.656271
# True                289.149766  267.113056  268.589780  263.129000  264.150842

# %%
df.groupby(['dist_bucket_str']).mean()[]
# Out:
#                     realSum  room_shared  room_private  person_capacity  \
# dist_bucket_str
# False            188.685736     0.020833      0.651620         2.792824
# True             264.650124     0.006899      0.358366         3.157593
#
#                  host_is_superhost     multi       biz  cleanliness_rating  \
# dist_bucket_str
# False                     0.219907  0.362269  0.140046            9.375000
# True                      0.256959  0.290563  0.354044            9.389711
#
#                  guest_satisfaction_overall  bedrooms       dist  metro_dist  \
# dist_bucket_str
# False                             93.067130  1.177083  12.766991    4.164505
# True                              92.602815  1.150377   3.030891    0.623569
#
#                  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# dist_bucket_str
# False             69.441177         5.553322  132.434958         4.973783
# ...

# %%
#Box & Whisker per Host Status
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="cleanliness_rating", 
            y="dist_bucket_str",
           width=.7)

plt.title('Distribution of cleanliness per City', fontsize=20)
plt.xlabel('Cleanliness Rating', fontsize=16);
plt.ylabel('Cleanliness', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
df.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
# 4  485.552926  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  ...  rest_index  rest_index_norm      lng  \
# 0                        93.0  ...   98.253896         6.846473  4.90569
# ...

# %%
df.groupby(['City'])['realSum'].mean().sort_values()
# Out:
# City
# athens       148.259805
# budapest     172.966193
# rome         202.877121
# vienna       230.394338
# berlin       232.713947
# lisbon       237.960073
# barcelona    274.692900
# london       325.910320
# paris        371.862633
# amsterdam    511.014946
# Name: realSum, dtype: float64

# %%
a = df.groupby(['City'])[['realSum','dist', 'metro_dist','cleanliness_rating', 'guest_satisfaction_overall', 'host_is_superhost']].mean().sort_values(by='realSum')

# %%
a
# Out:
#               realSum      dist  metro_dist  cleanliness_rating  \
# City
# athens     148.259805  1.803195    0.478674            9.638378
# budapest   172.966193  1.869011    0.543827            9.477590
# rome       202.877121  3.028070    0.820142            9.515424
# vienna     230.394338  3.140462    0.526771            9.473401
# berlin     232.713947  5.264395    0.838414            9.460324
# lisbon     237.960073  1.966180    0.711405            9.370531
# barcelona  274.692900  2.111506    0.441139            9.290735
# london     325.910320  5.364814    1.015323            9.169788
# paris      371.862633  2.993283    0.227281            9.258177
# amsterdam  511.014946  2.892530    1.107310            9.458711
#
#            guest_satisfaction_overall  host_is_superhost
# City
# athens                      95.002652           0.428490
# budapest                    94.589641           0.379482
# rome                        93.124612           0.327230
# ...

# %%
a.plot.scatter(x='host_is_superhost', y='realSum')
# Out:
# <AxesSubplot:xlabel='host_is_superhost', ylabel='realSum'>

# %%
x = a['host_is_superhost']
y = a['realSum']
r = np.corrcoef(x, y)

# %%
r
# Out:
# array([[ 1.        , -0.52752438],
#        [-0.52752438,  1.        ]])

# %%
slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)
line = f'Regression line: y={intercept:.2f}+{slope:.2f}x, r={r:.2f}'


fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('Price')
ax.set_ylabel('Superhost')
ax.legend(facecolor='white')
plt.show()

# %%
df.groupby(['City', 'room_type'])[['realSum','dist']].mean()
# Out:
#                               realSum      dist
# City      room_type
# amsterdam Entire home/apt  636.952478  2.689252
#           Private room     373.542809  3.100699
#           Shared room      280.903616  4.548634
# athens    Entire home/apt  151.304062  1.801633
#           Private room     112.838060  1.826949
#           Shared room       78.610490  1.637747
# barcelona Entire home/apt  542.096789  1.875932
#           Private room     213.480008  2.156939
#           Shared room      124.068083  3.855703
# berlin    Entire home/apt  335.911669  5.121004
#           Private room     177.719224  5.432673
#           Shared room      153.192356  3.453282
# budapest  Entire home/apt  180.610629  1.703050
#           Private room     109.137759  3.205756
#           Shared room      126.830447  4.336207
# lisbon    Entire home/apt  282.135082  1.767758
#           Private room     148.902035  2.368675
#           Shared room      103.062725  2.511603
# ...

# %%
df[(df['dist'] <= 1) & (df['City'].isin(['athens', 'budapest'])) & (df['room_type'] == 'Entire home/apt')].groupby(['City', 'room_type'])[['realSum','dist']].median()
# Out:
#                              realSum      dist
# City     room_type
# athens   Entire home/apt  179.738945  0.685839
# budapest Entire home/apt  170.136767  0.623336

# %%
listing_counts = europe_data.groupby('city').realSum.count().reset_index()
superhost_count = europe_data.groupby('city').host_is_superhost.sum().reset_index()
superhost_count['abbr'] = superhost_count.city.apply(lambda x: x[:3].upper())

listing_superhost_count = pd.merge(listing_counts, superhost_count).sort_values('realSum', ascending=False)
listing_superhost_count['perc'] = listing_superhost_count.apply(lambda row:
                                                                round((row['host_is_superhost'] / row['realSum'] * 100), 1), axis=1)
listing_superhost_count['perc'] = listing_superhost_count.perc.apply(lambda x: str(x)+"%")

listing_superhost_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 listing_counts = europe_data.groupby('city').realSum.count().reset_index()
#       2 superhost_count = europe_data.groupby('city').host_is_superhost.sum().reset_index()
#       3 superhost_count['abbr'] = superhost_count.city.apply(lambda x: x[:3].upper())
#
# NameError: name 'europe_data' is not defined

# %%
sns.set_theme(style='whitegrid')

f, ax = plt.subplots(figsize=(6, 5))

sns.set_color_codes('pastel')
sns.barplot(x='realSum', y='abbr', data=listing_superhost_count, label='total', color='#E8E8E8')

sns.set_color_codes('muted')
sns.barplot(x='host_is_superhost', y='abbr', data=listing_superhost_count, label='Superhosts', color='#FC814A')

ax.legend(ncol=2, loc='lower right', frameon=True)
ax.set(xlim=(0,10000), ylabel='', xlabel='')
ax.bar_label(ax.containers[1], labels=listing_superhost_count.perc, label_type='edge', padding=5)
sns.despine(left=True, bottom=True)

plt.title('Superhost to total Listings per City')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 6>()
#       3 f, ax = plt.subplots(figsize=(6, 5))
#       5 sns.set_color_codes('pastel')
# ----> 6 sns.barplot(x='realSum', y='abbr', data=listing_superhost_count, label='total', color='#E8E8E8')
#       8 sns.set_color_codes('muted')
#       9 sns.barplot(x='host_is_superhost', y='abbr', data=listing_superhost_count, label='Superhosts', color='#FC814A')
#
# NameError: name 'listing_superhost_count' is not defined

# %%
recommendtion

- fair comparison
All of them plan to go to Paris

-- 3 groups of ppl going to Paris

Scope
- recommend specific listings intead of the city
Scope at a minimum level
Specific city focus
based on the different recommendation
mini recommendation engine.

Allow the cusotmer to choose how close they are to the metro
price range
superhost
filtering on the dataset

building a recommendation.

real world scenario


different neighborhoods
deeper analysis


Hotel vs Airbnb

anOTHER DATASET on 
hotel data

between airbnb and hotel which one to pick

one city - manageable size of data
geolocation of the hotels
head to head

# %% [markdown]
# # MAPS... (next document)
